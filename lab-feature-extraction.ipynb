# %% [markdown]
# # Lab | Cleaning numerical data

# %% [markdown]
# 1.  Import the necessary libraries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re

# %% [markdown]
# 2.  Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df.

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %% [markdown]
# 3.  First look at its main features (head, shape, info).

# %%
display(customer_df.shape)
customer_df.head()
customer_df.info()
# Out:
# (9134, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %% [markdown]
# 4.  Rename the columns so they follow the PE8 (snake case).

# %%
customer_df.columns= customer_df.columns.str.lower()
customer_df

customer_df.columns = customer_df.columns.str.replace(' ','_')
customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
customer_df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %% [markdown]
# 5.  Change effective to date column to datetime format.

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'], format='%m/%d/%y')

# %%
customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# 6.  Check NaN values per column.

# %%
customer_df.isnull().sum(axis = 0)
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %% [markdown]
# 7.  Define a function that differentiates between continuous and discrete variables.
# Hint: A number of unique values might be useful.
# Store continuous data into a continuous variable and do the same for discrete and categorical.

# %%
customer_df.nunique()
#superstore['Country'].unique()
#superstore['Country'].value_counts()
# Out:
# customer                         9134
# state                               5
# customer_lifetime_value          8041
# response                            2
# coverage                            3
# education                           5
# effective_to_date                  59
# employmentstatus                    5
# gender                              2
# income                           5694
# location_code                       3
# marital_status                      3
# monthly_premium_auto              202
# months_since_last_claim            36
# months_since_policy_inception     100
# number_of_open_complaints           6
# number_of_policies                  9
# policy_type                         3
# policy                              9
# renew_offer_type                    4
# sales_channel                       4
# total_claim_amount               5106
# vehicle_class                       6
# vehicle_size                        3
# dtype: int64

# %%
numerical = customer_df._get_numeric_data()
numerical.T
# Out:
#                                        0            1             2     \
# customer_lifetime_value         2763.519279  6979.535903  12887.431650
# income                         56274.000000     0.000000  48767.000000
# monthly_premium_auto              69.000000    94.000000    108.000000
# months_since_last_claim           32.000000    13.000000     18.000000
# months_since_policy_inception      5.000000    42.000000     38.000000
# number_of_open_complaints          0.000000     0.000000      0.000000
# number_of_policies                 1.000000     8.000000      2.000000
# total_claim_amount               384.811147  1131.464935    566.472247
#
#                                       3             4             5     \
# customer_lifetime_value        7645.861827   2813.692575   8256.297800
# income                            0.000000  43836.000000  62902.000000
# monthly_premium_auto            106.000000     73.000000     69.000000
# ...

# %%
discrete = []
for x in numerical.columns: 
    if numerical[x].nunique() < 10: 
        discrete.append(x) 
print (discrete)

continuous = []
for x in numerical.columns: 
    if numerical[x].nunique() >= 10: 
        continuous.append(x) 
print (continuous)
# Out:
# ['number_of_open_complaints', 'number_of_policies']
# ['customer_lifetime_value', 'income', 'monthly_premium_auto', 'months_since_last_claim', 'months_since_policy_inception', 'total_claim_amount']

# %%
categorical = customer_df.select_dtypes('object')
categorical
# Out:
#      customer       state response  coverage education employmentstatus  \
# 0     BU79786  Washington       No     Basic  Bachelor         Employed
# 1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
# 2     AI49188      Nevada       No   Premium  Bachelor         Employed
# 3     WW63253  California       No     Basic  Bachelor       Unemployed
# 4     HB64268  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129  LA72316  California       No     Basic  Bachelor         Employed
# 9130  PK87824  California      Yes  Extended   College         Employed
# 9131  TD14365  California       No  Extended  Bachelor       Unemployed
# 9132  UP19263  California       No  Extended   College         Employed
# 9133  Y167826  California       No  Extended   College       Unemployed
#
#      gender location_code marital_status     policy_type        policy  \
# ...

# %% [markdown]
# 8.  For the categorical data, check if there is some kind of text in a variable so we would need to clean it.
# Hint: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.

# %%
categorical.head().T
# Out:
#                                0              1              2  \
# customer                 BU79786        QZ44356        AI49188
# state                 Washington        Arizona         Nevada
# response                      No             No             No
# coverage                   Basic       Extended        Premium
# education               Bachelor       Bachelor       Bachelor
# employmentstatus        Employed     Unemployed       Employed
# gender                         F              F              F
# location_code           Suburban       Suburban       Suburban
# marital_status           Married         Single        Married
# policy_type       Corporate Auto  Personal Auto  Personal Auto
# policy              Corporate L3    Personal L3    Personal L3
# renew_offer_type          Offer1         Offer3         Offer1
# sales_channel              Agent          Agent          Agent
# vehicle_class       Two-Door Car  Four-Door Car   Two-Door Car
# ...

# %%
# display(categorical['customer'].value_counts(dropna=False))

# Display value_counts for multiple columns:

for i in categorical.columns:
    x = categorical[i].value_counts(dropna=False)
    display(i,x)
# Out:
# 'customer'
# AC58002    1
# EU68825    1
# AB96670    1
# SL98898    1
# OF46381    1
#           ..
# JM47657    1
# LT32391    1
# ZS66375    1
# HP20623    1
# RB49468    1
# Name: customer, Length: 9134, dtype: int64
# 'state'
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
# 'response'
# No     7826
# Yes    1308
# Name: response, dtype: int64
# 'coverage'
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
# 'education'
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
# 'employmentstatus'
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64
# 'gender'
# F    4658
# M    4476
# Name: gender, dtype: int64
# ...

# %% [markdown]
# *No clean-up actions noted so far.

# %% [markdown]
# 9.  Get categorical features.

# %%
categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer          9134 non-null   object
#  1   state             9134 non-null   object
#  2   response          9134 non-null   object
#  3   coverage          9134 non-null   object
#  4   education         9134 non-null   object
#  5   employmentstatus  9134 non-null   object
#  6   gender            9134 non-null   object
#  7   location_code     9134 non-null   object
#  8   marital_status    9134 non-null   object
#  9   policy_type       9134 non-null   object
#  10  policy            9134 non-null   object
#  11  renew_offer_type  9134 non-null   object
#  12  sales_channel     9134 non-null   object
#  13  vehicle_class     9134 non-null   object
#  14  vehicle_size      9134 non-null   object
# dtypes: object(15)
# memory usage: 1.0+ MB

# %% [markdown]
# 10.  What should we do with the customer_id column?
#
# *I would drop this column as it does not appear to contain information that will be useful for our purposes.
# It also represents a unique value per customer.

# %% [markdown]
# # BEGINNING OF Lab | Cleaning categorical data

# %% [markdown]
# 1.  Import the necessary libraries if you are starting a new notebook.

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
from matplotlib.pyplot import figure
# %matplotlib inline

# %% [markdown]
# 2.  Load the continuous and discrete variables into continuous_df and discrete_df variables.

# %%
discrete_df = customer_df[customer_df.columns[customer_df.columns.isin(discrete)]]
discrete_df
# Out:
#       number_of_open_complaints  number_of_policies
# 0                             0                   1
# 1                             0                   8
# 2                             0                   2
# 3                             0                   7
# 4                             0                   1
# ...                         ...                 ...
# 9129                          0                   2
# 9130                          0                   1
# 9131                          3                   2
# 9132                          0                   3
# 9133                          0                   1
#
# [9134 rows x 2 columns]

# %%
continuous_df = customer_df[customer_df.columns[customer_df.columns.isin(continuous)]]
continuous_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# 3.  Plot a correlation matrix, what can you see?
#
# *From the correlation matrix, there are no high (above 0.9) correlations noted.
# There is a correlation noted between total_claim_amount and monthly_premium_auto and
# a negative correlation between total_claim_amount and income.
# Also there is a correlation between monthly_premium_auto and customer_lifetime_value.

# %%
figure(figsize=(8, 8), dpi=80)
correlations_matrix = numerical.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %% [markdown]
# 4.  Create a function to plot every discrete variables. Do the same with continuous variables
# (be careful, you may change the plot type to another one better suited for continuous data).

# %%
def plot_disc(Dataframe):
    for column in Dataframe.columns:
        sns.countplot(x=Dataframe[column])
        plt.show()
    return None

plot_disc(discrete_df)

# %%
def plot_disc(Dataframe):
    for column in Dataframe.columns:
        sns.histplot(x=Dataframe[column])
        plt.show()
    return None

plot_disc(continuous_df)

# %%
def plot_disc(Dataframe):
    for column in Dataframe.columns:
        sns.scatterplot(x=Dataframe[column],y =Dataframe['total_claim_amount'] )
        plt.show()
    return None

plot_disc(continuous_df)

# %% [markdown]
# 5.  What can you see in the plots?
#
# *Discrete variables: both plots are skewed to the right, with lots of variables in the lowest bucket;
#     0 for number_of_open_complaints and 1 for number_of_policies.
#
# *Continuous variables:  From the hist_plots, the ranges of the variables are visible.  The ranges are quick spread out,
#     so some scaling will be needed on the data.  Also there are outliers noted in the customer_lifetime_value
#     and monthly_premium_auto variables.
#     From the scatter plots, the sames correlation mentioned in point 3 is noted.  Also there are a number of 0 values
#     noted in the income variable.

# %% [markdown]
# 6.  Look for outliers in the continuous variables we have found. Hint: There was a good plot to do that.

# %%
# sns.boxplot(y=data['TIMELAG'])
# plt.show()

def plot_disc(Dataframe):
    for column in Dataframe.columns:
        sns.boxplot(y=Dataframe[column])
        plt.show()
    return None

plot_disc(continuous_df)


# sns.boxplot(y=continuous_df['customer_lifetime_value'])
# plt.show()

# %% [markdown]
# 7.  Have you found outliers? If you have, what should we do with them?
#
# *There are outliers noted in the customer_lifetime_value and monthly_premium_auto variables.  Also there are a number of
# 0 values noted in the income variable.  We can consider dropping the outliers
# noted in the customer_lifetime_value and monthly_premium_auto variables.  From below calculations, the outliers are less than
# 10% of the data in these variables.
# For the 0 values noted in the income variable, it seems unlikely that there would be so many 0 income values.  Without knowing too much about the customers/data collected,
# we can consider to either impute the mean for these values, or calculate a predicted value based on the other variables using
# a machine learning model, like KNeighborsClassifier, e.g.  Alternatively, given that there are so many 0 values (2317 of the 9134 rows),
# we can consider dropping this column.

# %%
# Checking how many values will be removed if the outliers are removed
iqr = np.percentile(customer_df['customer_lifetime_value'],75) - np.percentile(customer_df['customer_lifetime_value'],25)
upper_limit = np.percentile(customer_df['customer_lifetime_value'],75) + 1.5*iqr
print(upper_limit)

extraordinary_points = customer_df[customer_df['customer_lifetime_value'] > upper_limit]
len(extraordinary_points)  # THis checks the number of points that will be removed
# Out:
# 16414.039911750002
# 817

# %%
iqr = np.percentile(customer_df['monthly_premium_auto'],75) - np.percentile(customer_df['monthly_premium_auto'],25)
upper_limit = np.percentile(customer_df['monthly_premium_auto'],75) + 1.5*iqr
print(upper_limit)

extraordinary_points = customer_df[customer_df['monthly_premium_auto'] > upper_limit]
len(extraordinary_points)
# Out:
# 170.5
# 430

# %%
customer_df['income'].value_counts()
# Out:
# 0        2317
# 95697      12
# 26876       7
# 61108       7
# 25965       7
#          ...
# 36259       1
# 69011       1
# 38638       1
# 30092       1
# 51199       1
# Name: income, Length: 5694, dtype: int64

# %% [markdown]
# *Points 8 to 12 are covered in points 6 to 10 of the first part of this workbook.
#
# 8.  Check nan values per column.
# 9.  Define a function that differentiate between continuous and discrete variables.
# Hint: Number of unique values might be useful. Store continuous data into a continuous variable and do the same for discrete and categorical.
# 10.  for the categorical data, check if there is some kind of text in a variable so we would need to clean it.
# Hint: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.
# 11.  Get categorical features.
# 12.  What should we do with the customer id column?

# %% [markdown]
# # BEGINNING OF Lab | feature-extraction

# %% [markdown]
# 1. Open the categoricals variable we created before.
# categoricals = data.select_dtypes(np.object)
# categoricals.head()

# %%
categorical.head()
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  BU79786  Washington       No     Basic  Bachelor         Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor       Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor         Employed      F
# 3  WW63253  California       No     Basic  Bachelor       Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
# ...

# %% [markdown]
# 2. Plot all the categorical variables with the proper plot. What can you see?

# %%
def plot_disc(Dataframe):
    for column in Dataframe.columns:
        sns.countplot(x=Dataframe[column])
        plt.xticks(rotation=45)
        plt.show()
    return None

plot_disc(categorical.drop(['customer'],axis=1))

# %% [markdown]
# 3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?

# %% [markdown]
# *The Customer column contains redundant information, and we should drop this column.

# %% [markdown]
# 4. Plot time variable. Can you extract something from it?

# %%
x = customer_df['effective_to_date']
y = customer_df['total_claim_amount']
plt.scatter(x,y)
plt.xticks(rotation=45)
plt.show()

# sns.scatterplot(customer_df['effective_to_date'])
# plt.show()

# %% [markdown]
# <!-- The time variable appears to be gathered in weekly time buckets.  We could consider including a week number for this.  -->

# %% [markdown]
# *The time variable appears to be per week.  We could consider including a corresponding week number for this.
